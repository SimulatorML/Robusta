# %% [markdown]
# # Import

# %%
# Basic
import pandas as pd
import numpy as np

import warnings

warnings.simplefilter('ignore')

# ML Toolkit
from robusta.optimizer import GridSearchCV, RandomSearchCV, OptunaCV
from robusta.crossval import crossval_predict
from robusta.pipeline import *
from robusta.stack import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression
from dask_ml.preprocessing import RobustScaler

# Model
from robusta.testing import get_estimator, get_estimator_name
from robusta.testing import ESTIMATORS, PARAM_SPACE

# Plot
from jupyterthemes import jtplot
import matplotlib

jtplot.style('gruvboxd')
matplotlib.use('nbagg')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data

# %%
X, y = make_regression(n_samples=200, n_features=10, n_informative=2, 
                       random_state=666, noise=0.2)

X = pd.DataFrame(X)
y = pd.Series(y)

# %%
X
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.135661 -0.430775  0.585261 -2.744542 -2.091578 -0.527383 -0.104947
# 1   -1.162613  0.487434  1.891200  1.681331  1.465606 -0.827095  0.800757
# 2    1.479978 -1.492034  0.783114  0.876042  0.860270 -0.510942  1.000717
# 3    0.499060 -0.794232  0.282603  1.123826 -0.086081 -1.915057 -1.025033
# 4    0.081877  0.196557  0.778831 -0.079289 -1.728170  0.826598 -1.777999
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.943557 -0.082599 -0.867088  0.295086 -0.404854  1.203706  1.032915
# 196 -1.615359 -0.748560  0.209846  1.371128  0.688954 -0.666664  1.705340
# 197  0.861696 -2.155197 -0.749322  1.224041 -0.355526 -0.155421 -0.849080
# 198  1.037315 -0.395199 -2.165005  0.370486 -0.039071  0.047767  0.075644
# 199 -0.407942 -0.403481  1.123168  1.199984 -0.875175 -0.128041 -0.363663
#
#             7         8         9
# 0   -0.539386 -1.133136  0.290818
# 1   -0.345333 -0.089977  0.300130
# 2    0.904345 -0.215002  1.320471
# 3    1.696374 -0.890490 -0.510916
# 4   -0.420409  0.939043 -0.131891
# ..        ...       ...       ...
# 195  1.760090 -0.981685 -1.473304
# 196  0.176047  1.115852 -0.868293
# 197  0.519710  0.035508  1.253223
# 198  0.247760  2.023676 -0.760564
# 199 -0.356188  0.449313  0.322444
#
# [200 rows x 10 columns]

# %% [markdown]
# # Task

# %%
scoring = 'neg_mean_squared_error'
cv = 5

# %% [markdown]
# # Optimizer

# %% [markdown]
# ## Optuna

# %%
model = make_pipeline(
    StackingRegressor([
        ('knn', get_estimator('KNeighbors', 'regressor')),
        ('lin', get_estimator('LinearRegression', 'regressor')),
    ], 
        meta_estimator=get_estimator('Ridge', 'regressor'),
        n_jobs=None)
)

model
# Out:
# Pipeline(memory=None,
#          steps=[('stackingregressor',
#                  StackingRegressor(cv=5,
#                                    estimators=[('knn',
#                                                 KNeighborsRegressor(algorithm='auto',
#                                                                     leaf_size=30,
#                                                                     metric='minkowski',
#                                                                     metric_params=None,
#                                                                     n_jobs=None,
#                                                                     n_neighbors=5,
#                                                                     p=2,
#                                                                     weights='uniform')),
#                                                ('lin',
#                                                 LinearRegression(copy_X=True,
#                                                                  fit_intercept=True,
#                                                                  n_jobs=None,
#                                                                  normalize=False))],
#                                    join_X=False,
#                                    meta_estimator=Ridge(alpha=1.0, copy_X=True,
#                                                         fit_intercept=True,
#                                                         max_iter=None,
#                                                         normalize=False,
#                                                         random_state=None,
#                                                         solver='auto',
#                                                         tol=0.001),
#                                    n_digits=4, n_jobs=None, random_state=0,
#                                    scoring=None, test_avg=True, verbose=0))],
#          verbose=False)

# %%
optimizer = OptunaCV(model, cv, scoring, param_space=None, 
                     max_iter=10, verbose=2, n_jobs=-1)
optimizer.fit(X, y)

params = optimizer.best_params_
# Out:
# FOUND MODELS:
# {'stackingregressor__meta_estimator': Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#        normalize=False, random_state=None, solver='auto', tol=0.001),
#  'stackingregressor__knn': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform'),
#  'stackingregressor__lin': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)}
# FOUND PARAMETERS:
# {'stackingregressor__meta_estimator__alpha': (1e-06, 1000000.0, 'log'),
#  'stackingregressor__meta_estimator__fit_intercept': {False, True},
#  'stackingregressor__meta_estimator__normalize': {False, True},
#  'stackingregressor__knn__n_neighbors': (1, 30, 1),
#  'stackingregressor__knn__weights': {'distance', 'uniform'},
#  'stackingregressor__knn__algorithm': {'ball_tree', 'kd_tree'},
#  'stackingregressor__knn__leaf_size': (10, 100, 10),
#  'stackingregressor__knn__p': {1, 2},
#  'stackingregressor__lin__fit_intercept': {False, True}}
# [02:06:49] ITER: 1/10      SCORE: -0.0694 ± 0.0228      ETA: 37 sec
# stackingregressor__meta_estimator__alpha            3.8526720932705167
# stackingregressor__meta_estimator__fit_intercept                  True
# stackingregressor__meta_estimator__normalize                     False
# stackingregressor__knn__n_neighbors                                  4
# stackingregressor__knn__weights                               distance
# stackingregressor__knn__algorithm                              kd_tree
# stackingregressor__knn__leaf_size                                   10
# stackingregressor__knn__p                                            2
# stackingregressor__lin__fit_intercept                             True
# dtype: object
#
# [02:06:53] ITER: 2/10      SCORE: -0.0455 ± 0.0095      ETA: 33 sec
# stackingregressor__meta_estimator__alpha            0.040980805223454105
# stackingregressor__meta_estimator__fit_intercept                    True
# stackingregressor__meta_estimator__normalize                       False
# stackingregressor__knn__n_neighbors                                   25
# stackingregressor__knn__weights                                  uniform
# stackingregressor__knn__algorithm                              ball_tree
# stackingregressor__knn__leaf_size                                     60
# stackingregressor__knn__p                                              2
# stackingregressor__lin__fit_intercept                              False
# dtype: object
#
# [02:06:57] ITER: 3/10      SCORE: -288.1129 ± 35.8078      ETA: 29 sec
# stackingregressor__meta_estimator__alpha            5572.174972621346
# stackingregressor__meta_estimator__fit_intercept                False
# stackingregressor__meta_estimator__normalize                    False
# stackingregressor__knn__n_neighbors                                18
# stackingregressor__knn__weights                              distance
# stackingregressor__knn__algorithm                             kd_tree
# stackingregressor__knn__leaf_size                                  80
# stackingregressor__knn__p                                           1
# stackingregressor__lin__fit_intercept                            True
# dtype: object
#
# [02:07:02] ITER: 4/10      SCORE: -0.0463 ± 0.0095      ETA: 25 sec
# stackingregressor__meta_estimator__alpha            59.98773504641804
# stackingregressor__meta_estimator__fit_intercept                False
# stackingregressor__meta_estimator__normalize                     True
# stackingregressor__knn__n_neighbors                                 6
# stackingregressor__knn__weights                               uniform
# stackingregressor__knn__algorithm                             kd_tree
# stackingregressor__knn__leaf_size                                  50
# stackingregressor__knn__p                                           1
# stackingregressor__lin__fit_intercept                           False
# dtype: object
#
# [02:07:06] ITER: 5/10      SCORE: -1230.3226 ± 169.4459      ETA: 20 sec
# stackingregressor__meta_estimator__alpha            0.4822769917397945
# stackingregressor__meta_estimator__fit_intercept                  True
# stackingregressor__meta_estimator__normalize                      True
# stackingregressor__knn__n_neighbors                                 30
# stackingregressor__knn__weights                               distance
# stackingregressor__knn__algorithm                              kd_tree
# stackingregressor__knn__leaf_size                                   20
# stackingregressor__knn__p                                            2
# stackingregressor__lin__fit_intercept                            False
# dtype: object
#
# [02:07:10] ITER: 6/10      SCORE: -4691.1269 ± 576.2148      ETA: 16 sec
# stackingregressor__meta_estimator__alpha            9.6435626201128
# stackingregressor__meta_estimator__fit_intercept               True
# stackingregressor__meta_estimator__normalize                   True
# stackingregressor__knn__n_neighbors                               1
# stackingregressor__knn__weights                            distance
# stackingregressor__knn__algorithm                         ball_tree
# stackingregressor__knn__leaf_size                                30
# stackingregressor__knn__p                                         2
# stackingregressor__lin__fit_intercept                         False
# dtype: object
#
# [02:07:15] ITER: 7/10      SCORE: -0.3815 ± 0.1173      ETA: 12 sec
# stackingregressor__meta_estimator__alpha            1953.4588772275827
# stackingregressor__meta_estimator__fit_intercept                  True
# stackingregressor__meta_estimator__normalize                     False
# stackingregressor__knn__n_neighbors                                  3
# stackingregressor__knn__weights                                uniform
# stackingregressor__knn__algorithm                            ball_tree
# stackingregressor__knn__leaf_size                                   40
# stackingregressor__knn__p                                            2
# stackingregressor__lin__fit_intercept                             True
# dtype: object
#
# [02:07:19] ITER: 8/10      SCORE: -0.0458 ± 0.0093      ETA: 8 sec
# stackingregressor__meta_estimator__alpha            22.13852451266167
# stackingregressor__meta_estimator__fit_intercept                False
# stackingregressor__meta_estimator__normalize                     True
# stackingregressor__knn__n_neighbors                                16
# stackingregressor__knn__weights                               uniform
# stackingregressor__knn__algorithm                             kd_tree
# stackingregressor__knn__leaf_size                                  50
# stackingregressor__knn__p                                           1
# stackingregressor__lin__fit_intercept                            True
# dtype: object
#
# [02:07:23] ITER: 9/10      SCORE: -605.4776 ± 80.1281      ETA: 4 sec
# stackingregressor__meta_estimator__alpha            0.17554297149939016
# stackingregressor__meta_estimator__fit_intercept                   True
# stackingregressor__meta_estimator__normalize                       True
# stackingregressor__knn__n_neighbors                                  10
# stackingregressor__knn__weights                                distance
# stackingregressor__knn__algorithm                               kd_tree
# stackingregressor__knn__leaf_size                                    20
# stackingregressor__knn__p                                             1
# stackingregressor__lin__fit_intercept                             False
# dtype: object
#
# [02:07:28] ITER: 10/10      SCORE: -0.0456 ± 0.0091      ETA: 0 ms
# stackingregressor__meta_estimator__alpha            3.524646543558122e-05
# stackingregressor__meta_estimator__fit_intercept                    False
# stackingregressor__meta_estimator__normalize                         True
# stackingregressor__knn__n_neighbors                                    22
# stackingregressor__knn__weights                                   uniform
# stackingregressor__knn__algorithm                                 kd_tree
# stackingregressor__knn__leaf_size                                      50
# stackingregressor__knn__p                                               1
# stackingregressor__lin__fit_intercept                                True
# dtype: object
#
# Iterations limit exceed!
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-48-0e1cc8df6321> in <module>
#       1 optimizer = OptunaCV(model, cv, scoring, param_space=None,
#       2                      max_iter=10, verbose=2, n_jobs=-1)
# ----> 3 optimizer.fit(X, y)
#       4
#       5 params = optimizer.best_params_
#
# ~/anaconda/lib/python3.6/site-packages/robusta/optimizer/base.py in fit(self, X, y, groups)
#     288
#     289         # Custom core fit
# --> 290         self._fit(X, y, groups)
#     291
#     292         return self
#
# ~/anaconda/lib/python3.6/site-packages/robusta/optimizer/optuna.py in _fit(self, X, y, groups)
#      67             self.study = optuna.create_study(direction='maximize', sampler=sampler)
#      68
# ---> 69         self.study.optimize(objective)
#      70
#      71         return self
#
# ~/anaconda/lib/python3.6/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch)
#     246
#     247         if n_jobs == 1:
# --> 248             self._optimize_sequential(func, n_trials, timeout, catch)
#     249         else:
#     250             self._optimize_parallel(func, n_trials, timeout, n_jobs, catch)
#
# ~/anaconda/lib/python3.6/site-packages/optuna/study.py in _optimize_sequential(self, func, n_trials, timeout, catch)
#     361                     break
#     362
# --> 363             self._run_trial(func, catch)
#     364
#     365     def _optimize_parallel(
#
# ~/anaconda/lib/python3.6/site-packages/optuna/study.py in _run_trial(self, func, catch)
#     435
#     436         try:
# --> 437             result = func(trial)
#     438         except structs.TrialPruned as e:
#     439             message = 'Setting status of trial#{} as {}. {}'.format(trial_number,
#
# ~/anaconda/lib/python3.6/site-packages/robusta/optimizer/optuna.py in objective(trial)
#      59         def objective(trial):
#      60             params = self._get_params(trial)
# ---> 61             score = self.eval_params(params, X, y, groups)
#      62             return score
#      63
#
# ~/anaconda/lib/python3.6/site-packages/robusta/optimizer/base.py in eval_params(self, params, X, y, groups)
#     173     def eval_params(self, params, X, y, groups=None):
#     174
# --> 175         self._check_max_iter()
#     176         self._check_max_time()
#     177
#
# ~/anaconda/lib/python3.6/site-packages/robusta/optimizer/base.py in _check_max_iter(self)
#     259             if self.max_iter <= self.n_iters_:
#     260                 if self.verbose: print('Iterations limit exceed!')
# --> 261                 raise KeyboardInterrupt
#     262
#     263
#
# KeyboardInterrupt:
