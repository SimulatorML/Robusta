# %% [markdown]
# # Import

# %%
# Basic
import pandas as pd
import numpy as np

import warnings

warnings.simplefilter('ignore')

# ML Toolkit
from robusta.preprocessing import ColumnRenamer

# Data
from catboost.datasets import titanic

# %% [markdown]
# # Data

# %%
df, _ = titanic()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Renamer

# %% [markdown]
# ## –

# %%
renamer = ColumnRenamer()
renamer.fit_transform(df).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Iterable

# %%
renamer = ColumnRenamer(range(12))
renamer.fit_transform(df).head()
# Out:
#    0  1  2                                                  3       4     5  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    6  7                 8        9    10 11
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
renamer = ColumnRenamer(np.random.permutation(df.columns))
renamer.fit_transform(df).head()
# Out:
#    Parch  PassengerId  Sex                                              SibSp  \
# 0      1            0    3                            Braund, Mr. Owen Harris
# 1      2            1    1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3            1    3                             Heikkinen, Miss. Laina
# 3      4            1    1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5            0    3                           Allen, Mr. William Henry
#
#    Ticket   Age  Embarked  Name          Survived    Cabin  Fare Pclass
# 0    male  22.0         1     0         A/5 21171   7.2500   NaN      S
# 1  female  38.0         1     0          PC 17599  71.2833   C85      C
# 2  female  26.0         0     0  STON/O2. 3101282   7.9250   NaN      S
# 3  female  35.0         1     0            113803  53.1000  C123      S
# 4    male  35.0         0     0            373450   8.0500   NaN      S

# %% [markdown]
# ## String

# %%
renamer = ColumnRenamer('x')
renamer.fit_transform(df).head()
# Out:
#    x0  x1  x2                                                 x3      x4  \
# 0   1   0   3                            Braund, Mr. Owen Harris    male
# 1   2   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2   3   1   3                             Heikkinen, Miss. Laina  female
# 3   4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   5   0   3                           Allen, Mr. William Henry    male
#
#      x5  x6  x7                x8       x9   x10 x11
# 0  22.0   1   0         A/5 21171   7.2500   NaN   S
# 1  38.0   1   0          PC 17599  71.2833   C85   C
# 2  26.0   0   0  STON/O2. 3101282   7.9250   NaN   S
# 3  35.0   1   0            113803  53.1000  C123   S
# 4  35.0   0   0            373450   8.0500   NaN   S

# %% [markdown]
# ## Prefix / Suffix

# %%
renamer = ColumnRenamer(prefix='base_')
renamer.fit_transform(df).head()
# Out:
#    base_PassengerId  base_Survived  base_Pclass  \
# 0                 1              0            3
# 1                 2              1            1
# 2                 3              1            3
# 3                 4              1            1
# 4                 5              0            3
#
#                                            base_Name base_Sex  base_Age  \
# 0                            Braund, Mr. Owen Harris     male      22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   female      38.0
# 2                             Heikkinen, Miss. Laina   female      26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   female      35.0
# 4                           Allen, Mr. William Henry     male      35.0
#
#    base_SibSp  base_Parch       base_Ticket  base_Fare base_Cabin  \
# 0           1           0         A/5 21171     7.2500        NaN
# 1           1           0          PC 17599    71.2833        C85
# ...

# %%
renamer = ColumnRenamer(suffix='_new')
renamer.fit_transform(df).head()
# Out:
#    PassengerId_new  Survived_new  Pclass_new  \
# 0                1             0           3
# 1                2             1           1
# 2                3             1           3
# 3                4             1           1
# 4                5             0           3
#
#                                             Name_new Sex_new  Age_new  \
# 0                            Braund, Mr. Owen Harris    male     22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.0
# 2                             Heikkinen, Miss. Laina  female     26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.0
# 4                           Allen, Mr. William Henry    male     35.0
#
#    SibSp_new  Parch_new        Ticket_new  Fare_new Cabin_new Embarked_new
# 0          1          0         A/5 21171    7.2500       NaN            S
# 1          1          0          PC 17599   71.2833       C85            C
# ...

# %%
renamer = ColumnRenamer(prefix='t_', suffix='+1')
renamer.fit_transform(df).head()
# Out:
#    t_PassengerId+1  t_Survived+1  t_Pclass+1  \
# 0                1             0           3
# 1                2             1           1
# 2                3             1           3
# 3                4             1           1
# 4                5             0           3
#
#                                             t_Name+1 t_Sex+1  t_Age+1  \
# 0                            Braund, Mr. Owen Harris    male     22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female     38.0
# 2                             Heikkinen, Miss. Laina  female     26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     35.0
# 4                           Allen, Mr. William Henry    male     35.0
#
#    t_SibSp+1  t_Parch+1        t_Ticket+1  t_Fare+1 t_Cabin+1 t_Embarked+1
# 0          1          0         A/5 21171    7.2500       NaN            S
# 1          1          0          PC 17599   71.2833       C85            C
# ...

# %%
renamer = ColumnRenamer('svd', prefix='pro_')
renamer.fit_transform(df).head()
# Out:
#    pro_svd0  pro_svd1  pro_svd2  \
# 0         1         0         3
# 1         2         1         1
# 2         3         1         3
# 3         4         1         1
# 4         5         0         3
#
#                                             pro_svd3 pro_svd4  pro_svd5  \
# 0                            Braund, Mr. Owen Harris     male      22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   female      38.0
# 2                             Heikkinen, Miss. Laina   female      26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   female      35.0
# 4                           Allen, Mr. William Henry     male      35.0
#
#    pro_svd6  pro_svd7          pro_svd8  pro_svd9 pro_svd10 pro_svd11
# 0         1         0         A/5 21171    7.2500       NaN         S
# 1         1         0          PC 17599   71.2833       C85         C
# 2         0         0  STON/O2. 3101282    7.9250       NaN         S
# ...

# %%
features = list(map(lambda x: chr(x+ord('A')), range(12)))
renamer = ColumnRenamer(features, suffix='_new')
renamer.fit_transform(df).head()
# Out:
#    A_new  B_new  C_new                                              D_new  \
# 0      1      0      3                            Braund, Mr. Owen Harris
# 1      2      1      1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3      1      3                             Heikkinen, Miss. Laina
# 3      4      1      1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5      0      3                           Allen, Mr. William Henry
#
#     E_new  F_new  G_new  H_new             I_new    J_new K_new L_new
# 0    male   22.0      1      0         A/5 21171   7.2500   NaN     S
# 1  female   38.0      1      0          PC 17599  71.2833   C85     C
# 2  female   26.0      0      0  STON/O2. 3101282   7.9250   NaN     S
# 3  female   35.0      1      0            113803  53.1000  C123     S
# 4    male   35.0      0      0            373450   8.0500   NaN     S

# %% [markdown]
# ## Callable

# %%
renamer = ColumnRenamer(lambda x: x.upper(), suffix='_up')
renamer.fit_transform(df).head()
# Out:
#    PASSENGERID_up  SURVIVED_up  PCLASS_up  \
# 0               1            0          3
# 1               2            1          1
# 2               3            1          3
# 3               4            1          1
# 4               5            0          3
#
#                                              NAME_up  SEX_up  AGE_up  \
# 0                            Braund, Mr. Owen Harris    male    22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0
# 2                             Heikkinen, Miss. Laina  female    26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35.0
# 4                           Allen, Mr. William Henry    male    35.0
#
#    SIBSP_up  PARCH_up         TICKET_up  FARE_up CABIN_up EMBARKED_up
# 0         1         0         A/5 21171   7.2500      NaN           S
# 1         1         0          PC 17599  71.2833      C85           C
# 2         0         0  STON/O2. 3101282   7.9250      NaN           S
# ...

# %%
renamer = ColumnRenamer(lambda x: x[:3])
renamer.fit_transform(df).head()
# Out:
#    Pas  Sur  Pcl                                                Nam     Sex  \
# 0    1    0    3                            Braund, Mr. Owen Harris    male
# 1    2    1    1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2    3    1    3                             Heikkinen, Miss. Laina  female
# 3    4    1    1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4    5    0    3                           Allen, Mr. William Henry    male
#
#     Age  Sib  Par               Tic      Far   Cab Emb
# 0  22.0    1    0         A/5 21171   7.2500   NaN   S
# 1  38.0    1    0          PC 17599  71.2833   C85   C
# 2  26.0    0    0  STON/O2. 3101282   7.9250   NaN   S
# 3  35.0    1    0            113803  53.1000  C123   S
# 4  35.0    0    0            373450   8.0500   NaN   S
